# %% [markdown]
# # Hackathon Challenge: Predicting Restaurant Annual Turnover
#
# This notebook outlines the process of building a machine learning model to predict the annual turnover of restaurants across India based on various features provided in the dataset.

# %% [markdown]
# ## Import Necessary Libraries

# %%
# Import necessary libraries
import pandas as pd
import optuna
from datetime import datetime
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.metrics import mean_squared_error
from math import sqrt
from lightgbm import LGBMRegressor

# Load and preprocess the datasets
train_df = pd.read_csv('../data/Train_dataset_(1).csv')
test_df = pd.read_csv('../data/Test_dataset_(1).csv')

# Adjusted Feature Engineering
def feature_engineering(df):
    df['Opening Day of Restaurant'] = pd.to_datetime(df['Opening Day of Restaurant'], errors='coerce', dayfirst=True)
    df['Year Opened'] = df['Opening Day of Restaurant'].dt.year
    current_year = datetime.now().year
    df['Restaurant Age'] = current_year - df['Year Opened']
    df['Cuisine Count'] = df['Cuisine'].apply(lambda x: len(x.split(',')) if pd.notnull(x) else 0)
    df.drop(['Opening Day of Restaurant', 'Cuisine'], axis=1, inplace=True)
    return df

train_df = feature_engineering(train_df)
test_df = feature_engineering(test_df)



X = train_df.drop(['Annual Turnover', 'Registration Number'], axis=1)
y = train_df['Annual Turnover']
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.3, random_state=59)

categorical_features = ['City', 'Restaurant Location', 'Endorsed By', 'Restaurant Type', 'Restaurant Theme']
numerical_features = [col for col in train_df.columns if col not in categorical_features + ['Annual Turnover', 'Registration Number']]

preprocessor = ColumnTransformer(
    transformers=[
        ('num', SimpleImputer(strategy='mean'), numerical_features),
        ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_features)
    ]
)

def objective(trial):
    # Suggest parameters for the LightGBM model
    param = {
        'objective': 'regression',
        'metric': 'rmse',
        'verbosity': -1,
        'boosting_type': trial.suggest_categorical('boosting_type', ['gbdt']),
        'learning_rate': trial.suggest_float('learning_rate', 0.005, 0.05, log=True),
        'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
        'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
        'num_leaves': trial.suggest_int('num_leaves', 31, 128),  # Reduce for smaller datasets
        'feature_fraction': trial.suggest_float('feature_fraction', 0.5, 0.9),
        'bagging_fraction': trial.suggest_float('bagging_fraction', 0.5, 0.9),
        'bagging_freq': trial.suggest_int('bagging_freq', 1, 7),
        'min_child_samples': trial.suggest_int('min_child_samples', 10, 50),  # Increase for overfitting control
        'max_depth': trial.suggest_int('max_depth', 5, 15),  # Limiting depth for control overfitting
        'min_split_gain': trial.suggest_float('min_split_gain', 0, 0.1),  # Additional control for splitting
        'subsample': trial.suggest_float('subsample', 0.7, 1.0),  # Similar to bagging_fraction but can be tested separately
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.7, 1.0),  # Control overfitting
    }

    # Preprocess the data
    X_train_preprocessed = preprocessor.fit_transform(X_train)
    X_val_preprocessed = preprocessor.transform(X_val)

    # Fit the model with early stopping
    model = LGBMRegressor(**param)
    # Note: Specify eval_set and early_stopping_rounds within fit() method
    model.fit(
        X_train_preprocessed, 
        y_train, 
        eval_set=[(X_val_preprocessed, y_val)]
    )
    
    preds = model.predict(X_val_preprocessed, num_iteration=model.best_iteration_)
    rmse = sqrt(mean_squared_error(y_val, preds))
    return rmse


study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=100)



# Train the model with the best parameters
best_params = {k: v for k, v in study.best_trial.params.items() if k not in ['early_stopping_rounds', 'eval_metric', 'eval_set']}

# Initialize and fit the model with corrected parameters within the pipeline
model = Pipeline([
    ('preprocessor', preprocessor),
    ('model', LGBMRegressor(**best_params))
])
model.fit(X_train, y_train)

# Make predictions and prepare for submission
val_predictions = model.predict(X_val)
rmse_val = sqrt(mean_squared_error(y_val, val_predictions))
print(f"Validation RMSE: {rmse_val}")

test_predictions = model.predict(test_df.drop(['Registration Number'], axis=1))
submission_df = pd.DataFrame({
    'Registration Number': test_df['Registration Number'],
    'Annual Turnover': test_predictions
})
submission_path = '../data/submission_lgb_v5.csv'
submission_df.to_csv(submission_path, index=False)
# Out:
# [I 2024-02-09 21:18:55,498] A new study created in memory with name: no-name-55178fea-96a1-40e9-a3fe-798198a8ed57
# /tmp/ipykernel_20688/1978454258.py:100: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_20688/1978454258.py:101: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# [I 2024-02-09 21:18:55,607] Trial 0 finished with value: 19230923.21457975 and parameters: {'boosting_type': 'gbdt', 'learning_rate': 0.009108734594498165, 'lambda_l1': 0.07587625226343363, 'lambda_l2': 4.640687509698562, 'num_leaves': 37, 'feature_fraction': 0.7729788647408471, 'bagging_fraction': 0.5185399928756116, 'bagging_freq': 5, 'min_child_samples': 19, 'max_depth': 14, 'min_split_gain': 0.012572151206218997, 'subsample': 0.8754632465851877, 'colsample_bytree': 0.8241641844018247}. Best is trial 0 with value: 19230923.21457975.
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000361 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1276
# [LightGBM] [Info] Number of data points in the train set: 2445, number of used features: 59
# [LightGBM] [Info] Start training from score 30833496.932515
# /tmp/ipykernel_20688/1978454258.py:100: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_20688/1978454258.py:101: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# [I 2024-02-09 21:18:55,717] Trial 1 finished with value: 18959435.723572865 and parameters: {'boosting_type': 'gbdt', 'learning_rate': 0.01465497011504406, 'lambda_l1': 0.00016137375415387233, 'lambda_l2': 5.083727087343212e-06, 'num_leaves': 127, 'feature_fraction': 0.816258508227192, 'bagging_fraction': 0.6115003833681139, 'bagging_freq': 5, 'min_child_samples': 40, 'max_depth': 10, 'min_split_gain': 0.019531877711114743, 'subsample': 0.7731158081727677, 'colsample_bytree': 0.7859411570380794}. Best is trial 1 with value: 18959435.723572865.
# /tmp/ipykernel_20688/1978454258.py:100: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_20688/1978454258.py:101: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# [I 2024-02-09 21:18:55,832] Trial 2 finished with value: 18996249.409414258 and parameters: {'boosting_type': 'gbdt', 'learning_rate': 0.014152512876648473, 'lambda_l1': 9.863316596898763e-07, 'lambda_l2': 7.876428134495845e-08, 'num_leaves': 120, 'feature_fraction': 0.827786230706191, 'bagging_fraction': 0.6766711938749423, 'bagging_freq': 2, 'min_child_samples': 34, 'max_depth': 11, 'min_split_gain': 0.06465832312084886, 'subsample': 0.9915106455620604, 'colsample_bytree': 0.9451009624302075}. Best is trial 1 with value: 18959435.723572865.
# /tmp/ipykernel_20688/1978454258.py:100: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_20688/1978454258.py:101: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# [I 2024-02-09 21:18:55,922] Trial 3 finished with value: 19072906.604617596 and parameters: {'boosting_type': 'gbdt', 'learning_rate': 0.015186443340167732, 'lambda_l1': 4.643844063342328e-05, 'lambda_l2': 8.804216153856737e-08, 'num_leaves': 60, 'feature_fraction': 0.844466831495343, 'bagging_fraction': 0.8617243006031834, 'bagging_freq': 3, 'min_child_samples': 32, 'max_depth': 6, 'min_split_gain': 0.06916821849268087, 'subsample': 0.9337926382664659, 'colsample_bytree': 0.8775966679680851}. Best is trial 1 with value: 18959435.723572865.
# /tmp/ipykernel_20688/1978454258.py:100: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_20688/1978454258.py:101: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# [I 2024-02-09 21:18:56,034] Trial 4 finished with value: 19367628.71047757 and parameters: {'boosting_type': 'gbdt', 'learning_rate': 0.0061857766436483825, 'lambda_l1': 0.00017401710391506554, 'lambda_l2': 1.0420484105877683e-08, 'num_leaves': 69, 'feature_fraction': 0.7976893860343552, 'bagging_fraction': 0.5495394108316374, 'bagging_freq': 5, 'min_child_samples': 12, 'max_depth': 7, 'min_split_gain': 0.01589798041134005, 'subsample': 0.9112948477549645, 'colsample_bytree': 0.8448460893336509}. Best is trial 1 with value: 18959435.723572865.
# /tmp/ipykernel_20688/1978454258.py:100: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_20688/1978454258.py:101: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# [I 2024-02-09 21:18:56,155] Trial 5 finished with value: 18909572.184272446 and parameters: {'boosting_type': 'gbdt', 'learning_rate': 0.04517345884723388, 'lambda_l1': 1.7103696770604452e-05, 'lambda_l2': 0.13266978628752424, 'num_leaves': 125, 'feature_fraction': 0.7916286123842702, 'bagging_fraction': 0.8116671491428293, 'bagging_freq': 4, 'min_child_samples': 38, 'max_depth': 7, 'min_split_gain': 0.02076421086354323, 'subsample': 0.8302438195306084, 'colsample_bytree': 0.9139208210464167}. Best is trial 5 with value: 18909572.184272446.
# /tmp/ipykernel_20688/1978454258.py:100: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_20688/1978454258.py:101: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# [I 2024-02-09 21:18:56,257] Trial 6 finished with value: 19133448.541492976 and parameters: {'boosting_type': 'gbdt', 'learning_rate': 0.01033291615413911, 'lambda_l1': 1.4622765145337774e-06, 'lambda_l2': 2.8436745299708437e-05, 'num_leaves': 83, 'feature_fraction': 0.78114477193143, 'bagging_fraction': 0.636986722895959, 'bagging_freq': 4, 'min_child_samples': 43, 'max_depth': 11, 'min_split_gain': 0.015274933170197813, 'subsample': 0.8581254336096897, 'colsample_bytree': 0.9476837807641152}. Best is trial 5 with value: 18909572.184272446.
# /tmp/ipykernel_20688/1978454258.py:100: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_20688/1978454258.py:101: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# [I 2024-02-09 21:18:56,404] Trial 7 finished with value: 19475070.01270475 and parameters: {'boosting_type': 'gbdt', 'learning_rate': 0.005229394516657034, 'lambda_l1': 6.077715556617789e-08, 'lambda_l2': 0.000230404315123954, 'num_leaves': 95, 'feature_fraction': 0.5791521897105757, 'bagging_fraction': 0.8118828203712882, 'bagging_freq': 1, 'min_child_samples': 21, 'max_depth': 14, 'min_split_gain': 0.014480350809251797, 'subsample': 0.9133156769754901, 'colsample_bytree': 0.8525465533737073}. Best is trial 5 with value: 18909572.184272446.
# /tmp/ipykernel_20688/1978454258.py:100: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_20688/1978454258.py:101: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# [I 2024-02-09 21:18:56,496] Trial 8 finished with value: 18868951.024091516 and parameters: {'boosting_type': 'gbdt', 'learning_rate': 0.022012936559820003, 'lambda_l1': 4.839382192809467e-07, 'lambda_l2': 1.613496848051161e-06, 'num_leaves': 123, 'feature_fraction': 0.5110120478899309, 'bagging_fraction': 0.5739378983504357, 'bagging_freq': 2, 'min_child_samples': 49, 'max_depth': 7, 'min_split_gain': 0.047526694876870314, 'subsample': 0.9074687914022835, 'colsample_bytree': 0.7194346985992465}. Best is trial 8 with value: 18868951.024091516.
# /tmp/ipykernel_20688/1978454258.py:100: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_20688/1978454258.py:101: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# [I 2024-02-09 21:18:56,607] Trial 9 finished with value: 18909894.385400444 and parameters: {'boosting_type': 'gbdt', 'learning_rate': 0.02434947706260161, 'lambda_l1': 4.708750998741187e-07, 'lambda_l2': 1.2563786324394083e-05, 'num_leaves': 32, 'feature_fraction': 0.8656288182578888, 'bagging_fraction': 0.666392346265273, 'bagging_freq': 7, 'min_child_samples': 42, 'max_depth': 9, 'min_split_gain': 0.04791094847561361, 'subsample': 0.825996755513354, 'colsample_bytree': 0.9213597777018948}. Best is trial 8 with value: 18868951.024091516.
# /tmp/ipykernel_20688/1978454258.py:100: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_20688/1978454258.py:101: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# [I 2024-02-09 21:18:56,749] Trial 10 finished with value: 18903290.14344311 and parameters: {'boosting_type': 'gbdt', 'learning_rate': 0.026103189334137772, 'lambda_l1': 0.01964315778582893, 'lambda_l2': 0.020158118927505856, 'num_leaves': 103, 'feature_fraction': 0.5158815411444426, 'bagging_fraction': 0.7435514599155215, 'bagging_freq': 1, 'min_child_samples': 50, 'max_depth': 5, 'min_split_gain': 0.09415453431590441, 'subsample': 0.7082825884564636, 'colsample_bytree': 0.7075662130384562}. Best is trial 8 with value: 18868951.024091516.
# /tmp/ipykernel_20688/1978454258.py:100: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_20688/1978454258.py:101: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# [I 2024-02-09 21:18:56,873] Trial 11 finished with value: 18863166.79546964 and parameters: {'boosting_type': 'gbdt', 'learning_rate': 0.028027455420229042, 'lambda_l1': 0.035667984518404215, 'lambda_l2': 0.012072974362473591, 'num_leaves': 104, 'feature_fraction': 0.5008548754653956, 'bagging_fraction': 0.7457736729820372, 'bagging_freq': 1, 'min_child_samples': 50, 'max_depth': 5, 'min_split_gain': 0.09192345693175712, 'subsample': 0.7056986882694423, 'colsample_bytree': 0.7020473618676959}. Best is trial 11 with value: 18863166.79546964.
# /tmp/ipykernel_20688/1978454258.py:100: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_20688/1978454258.py:101: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# [I 2024-02-09 21:18:56,991] Trial 12 finished with value: 18893387.711799774 and parameters: {'boosting_type': 'gbdt', 'learning_rate': 0.02810914340841901, 'lambda_l1': 1.4973603326008897, 'lambda_l2': 0.012479865936955686, 'num_leaves': 107, 'feature_fraction': 0.6221001572574346, 'bagging_fraction': 0.7424840973766191, 'bagging_freq': 2, 'min_child_samples': 49, 'max_depth': 5, 'min_split_gain': 0.04249145953843738, 'subsample': 0.7185874665474217, 'colsample_bytree': 0.7026271765539579}. Best is trial 11 with value: 18863166.79546964.
# /tmp/ipykernel_20688/1978454258.py:100: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_20688/1978454258.py:101: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# [I 2024-02-09 21:18:57,119] Trial 13 finished with value: 18788044.567109007 and parameters: {'boosting_type': 'gbdt', 'learning_rate': 0.04162761338723816, 'lambda_l1': 0.006469080976457982, 'lambda_l2': 0.001667580216996528, 'num_leaves': 111, 'feature_fraction': 0.5149376126408773, 'bagging_fraction': 0.5928716569458122, 'bagging_freq': 2, 'min_child_samples': 47, 'max_depth': 8, 'min_split_gain': 0.09690457244611943, 'subsample': 0.7710571782270457, 'colsample_bytree': 0.7553121855273937}. Best is trial 13 with value: 18788044.567109007.
# /tmp/ipykernel_20688/1978454258.py:100: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_20688/1978454258.py:101: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# [I 2024-02-09 21:18:57,253] Trial 14 finished with value: 19058828.981927678 and parameters: {'boosting_type': 'gbdt', 'learning_rate': 0.04919374836301941, 'lambda_l1': 0.005225564936574962, 'lambda_l2': 0.0015590323340830684, 'num_leaves': 91, 'feature_fraction': 0.6576666212904957, 'bagging_fraction': 0.7269232932309995, 'bagging_freq': 1, 'min_child_samples': 26, 'max_depth': 8, 'min_split_gain': 0.09965308829106136, 'subsample': 0.7607187174828377, 'colsample_bytree': 0.7656134415558193}. Best is trial 13 with value: 18788044.567109007.
# /tmp/ipykernel_20688/1978454258.py:100: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_20688/1978454258.py:101: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# [I 2024-02-09 21:18:57,391] Trial 15 finished with value: 18843787.797067214 and parameters: {'boosting_type': 'gbdt', 'learning_rate': 0.03600093764229724, 'lambda_l1': 3.3480983326952685, 'lambda_l2': 1.5754470035833743, 'num_leaves': 108, 'feature_fraction': 0.5651247932374743, 'bagging_fraction': 0.7898876775891741, 'bagging_freq': 3, 'min_child_samples': 46, 'max_depth': 9, 'min_split_gain': 0.08312472673767314, 'subsample': 0.770265169728491, 'colsample_bytree': 0.7554217051814375}. Best is trial 13 with value: 18788044.567109007.
# /tmp/ipykernel_20688/1978454258.py:100: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_20688/1978454258.py:101: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# [I 2024-02-09 21:18:57,530] Trial 16 finished with value: 18802346.72245955 and parameters: {'boosting_type': 'gbdt', 'learning_rate': 0.042739909600212185, 'lambda_l1': 3.8838548721083885, 'lambda_l2': 3.862789064631697, 'num_leaves': 110, 'feature_fraction': 0.5717256923589614, 'bagging_fraction': 0.7956675754454225, 'bagging_freq': 3, 'min_child_samples': 45, 'max_depth': 9, 'min_split_gain': 0.08059768586301069, 'subsample': 0.7843652165855216, 'colsample_bytree': 0.998950605160372}. Best is trial 13 with value: 18788044.567109007.
# /tmp/ipykernel_20688/1978454258.py:100: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_20688/1978454258.py:101: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# [I 2024-02-09 21:18:57,689] Trial 17 finished with value: 18877578.581775848 and parameters: {'boosting_type': 'gbdt', 'learning_rate': 0.03667860317766166, 'lambda_l1': 0.520667054623905, 'lambda_l2': 0.3116515966209198, 'num_leaves': 68, 'feature_fraction': 0.7301108131149499, 'bagging_fraction': 0.8956942093024436, 'bagging_freq': 3, 'min_child_samples': 36, 'max_depth': 12, 'min_split_gain': 0.07705976012294304, 'subsample': 0.798285644159463, 'colsample_bytree': 0.9903729058857399}. Best is trial 13 with value: 18788044.567109007.
# /tmp/ipykernel_20688/1978454258.py:100: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_20688/1978454258.py:101: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# [I 2024-02-09 21:18:57,830] Trial 18 finished with value: 18957572.48613385 and parameters: {'boosting_type': 'gbdt', 'learning_rate': 0.03692697691918528, 'lambda_l1': 0.0024495119687877346, 'lambda_l2': 0.00042356331271443004, 'num_leaves': 114, 'feature_fraction': 0.5743647497264509, 'bagging_fraction': 0.5970165744751197, 'bagging_freq': 6, 'min_child_samples': 30, 'max_depth': 9, 'min_split_gain': 0.06198689806208399, 'subsample': 0.7436924583611851, 'colsample_bytree': 0.9956804209437558}. Best is trial 13 with value: 18788044.567109007.
# /tmp/ipykernel_20688/1978454258.py:100: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_20688/1978454258.py:101: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# [I 2024-02-09 21:18:57,953] Trial 19 finished with value: 18866657.476729494 and parameters: {'boosting_type': 'gbdt', 'learning_rate': 0.020198658107135795, 'lambda_l1': 0.20832495640576854, 'lambda_l2': 6.51712138793765, 'num_leaves': 93, 'feature_fraction': 0.6687151644169866, 'bagging_fraction': 0.5193612823884343, 'bagging_freq': 3, 'min_child_samples': 45, 'max_depth': 13, 'min_split_gain': 0.08445973691251137, 'subsample': 0.8058190376083971, 'colsample_bytree': 0.804755858521525}. Best is trial 13 with value: 18788044.567109007.
# /tmp/ipykernel_20688/1978454258.py:100: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_20688/1978454258.py:101: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# [I 2024-02-09 21:18:58,114] Trial 20 finished with value: 18949288.962977387 and parameters: {'boosting_type': 'gbdt', 'learning_rate': 0.019349893595100587, 'lambda_l1': 0.0018064834835183796, 'lambda_l2': 0.394825901786541, 'num_leaves': 83, 'feature_fraction': 0.606828099360694, 'bagging_fraction': 0.7009140563390058, 'bagging_freq': 2, 'min_child_samples': 26, 'max_depth': 10, 'min_split_gain': 0.03565872324583986, 'subsample': 0.7430416533420439, 'colsample_bytree': 0.745360672544601}. Best is trial 13 with value: 18788044.567109007.
# /tmp/ipykernel_20688/1978454258.py:100: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_20688/1978454258.py:101: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# [I 2024-02-09 21:18:58,264] Trial 21 finished with value: 18850804.839769594 and parameters: {'boosting_type': 'gbdt', 'learning_rate': 0.034603762908459845, 'lambda_l1': 6.232527954619401, 'lambda_l2': 3.192805179477418, 'num_leaves': 113, 'feature_fraction': 0.5545533597286385, 'bagging_fraction': 0.7979542364712363, 'bagging_freq': 3, 'min_child_samples': 45, 'max_depth': 8, 'min_split_gain': 0.08166815738117247, 'subsample': 0.7908108503911577, 'colsample_bytree': 0.7439906013284082}. Best is trial 13 with value: 18788044.567109007.
# /tmp/ipykernel_20688/1978454258.py:100: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_20688/1978454258.py:101: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# [I 2024-02-09 21:18:58,416] Trial 22 finished with value: 18924433.858734798 and parameters: {'boosting_type': 'gbdt', 'learning_rate': 0.042956723464003296, 'lambda_l1': 4.787841837705066, 'lambda_l2': 0.7457937461972802, 'num_leaves': 111, 'feature_fraction': 0.5480237456585042, 'bagging_fraction': 0.7913237145542613, 'bagging_freq': 4, 'min_child_samples': 46, 'max_depth': 9, 'min_split_gain': 0.07607754899094046, 'subsample': 0.7701192025907561, 'colsample_bytree': 0.7812491215305956}. Best is trial 13 with value: 18788044.567109007.
# /tmp/ipykernel_20688/1978454258.py:100: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_20688/1978454258.py:101: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# [I 2024-02-09 21:18:58,560] Trial 23 finished with value: 18912577.12769181 and parameters: {'boosting_type': 'gbdt', 'learning_rate': 0.03341997247594827, 'lambda_l1': 0.853281603726751, 'lambda_l2': 0.05115868331735247, 'num_leaves': 98, 'feature_fraction': 0.6025251209551129, 'bagging_fraction': 0.8599600774860109, 'bagging_freq': 3, 'min_child_samples': 40, 'max_depth': 8, 'min_split_gain': 0.08853427304992183, 'subsample': 0.7430395493583013, 'colsample_bytree': 0.7430374545491772}. Best is trial 13 with value: 18788044.567109007.
# /tmp/ipykernel_20688/1978454258.py:100: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_20688/1978454258.py:101: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# [I 2024-02-09 21:18:58,716] Trial 24 finished with value: 18892778.08534196 and parameters: {'boosting_type': 'gbdt', 'learning_rate': 0.04211748108853265, 'lambda_l1': 7.834060538756409, 'lambda_l2': 0.0019866366099209115, 'num_leaves': 117, 'feature_fraction': 0.5412007893050786, 'bagging_fraction': 0.8448865551124184, 'bagging_freq': 2, 'min_child_samples': 46, 'max_depth': 10, 'min_split_gain': 0.05857204281212469, 'subsample': 0.8200161120631015, 'colsample_bytree': 0.8813082304822972}. Best is trial 13 with value: 18788044.567109007.
# /tmp/ipykernel_20688/1978454258.py:100: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_20688/1978454258.py:101: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# [I 2024-02-09 21:18:58,888] Trial 25 finished with value: 18906231.788489584 and parameters: {'boosting_type': 'gbdt', 'learning_rate': 0.03100383010348223, 'lambda_l1': 0.1634973864697314, 'lambda_l2': 1.62179551540109, 'num_leaves': 101, 'feature_fraction': 0.653165073636503, 'bagging_fraction': 0.7695154277004512, 'bagging_freq': 4, 'min_child_samples': 38, 'max_depth': 11, 'min_split_gain': 0.09978618711673967, 'subsample': 0.7862459539428841, 'colsample_bytree': 0.8027611992661106}. Best is trial 13 with value: 18788044.567109007.
# /tmp/ipykernel_20688/1978454258.py:100: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_20688/1978454258.py:101: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# [I 2024-02-09 21:18:59,025] Trial 26 finished with value: 18805367.140088364 and parameters: {'boosting_type': 'gbdt', 'learning_rate': 0.04881596042831064, 'lambda_l1': 0.017308249310819077, 'lambda_l2': 8.863007028051031, 'num_leaves': 87, 'feature_fraction': 0.7177973522639549, 'bagging_fraction': 0.6928120991196762, 'bagging_freq': 3, 'min_child_samples': 43, 'max_depth': 9, 'min_split_gain': 0.07265441281701848, 'subsample': 0.7335779838448263, 'colsample_bytree': 0.7616610736939448}. Best is trial 13 with value: 18788044.567109007.
# /tmp/ipykernel_20688/1978454258.py:100: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_20688/1978454258.py:101: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# [I 2024-02-09 21:18:59,145] Trial 27 finished with value: 18901583.756223515 and parameters: {'boosting_type': 'gbdt', 'learning_rate': 0.04599575350383742, 'lambda_l1': 0.011195725392891058, 'lambda_l2': 0.10032029894289188, 'num_leaves': 74, 'feature_fraction': 0.720275473945061, 'bagging_fraction': 0.643040474269159, 'bagging_freq': 2, 'min_child_samples': 42, 'max_depth': 6, 'min_split_gain': 0.07442541648687506, 'subsample': 0.729997192922866, 'colsample_bytree': 0.8299939252591508}. Best is trial 13 with value: 18788044.567109007.
# /tmp/ipykernel_20688/1978454258.py:100: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_20688/1978454258.py:101: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# [I 2024-02-09 21:18:59,280] Trial 28 finished with value: 18983077.10981348 and parameters: {'boosting_type': 'gbdt', 'learning_rate': 0.039764826519834165, 'lambda_l1': 0.0012369162278718147, 'lambda_l2': 8.419303299212407, 'num_leaves': 57, 'feature_fraction': 0.688190805963421, 'bagging_fraction': 0.6738037665076392, 'bagging_freq': 4, 'min_child_samples': 35, 'max_depth': 8, 'min_split_gain': 0.05762144882477495, 'subsample': 0.8480790900374611, 'colsample_bytree': 0.8709939708103245}. Best is trial 13 with value: 18788044.567109007.
# /tmp/ipykernel_20688/1978454258.py:100: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_20688/1978454258.py:101: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# [I 2024-02-09 21:18:59,436] Trial 29 finished with value: 18983593.043378647 and parameters: {'boosting_type': 'gbdt', 'learning_rate': 0.048199475763614906, 'lambda_l1': 0.07659538662861737, 'lambda_l2': 0.0002019173298252494, 'num_leaves': 44, 'feature_fraction': 0.7104837713679777, 'bagging_fraction': 0.7087460395797001, 'bagging_freq': 6, 'min_child_samples': 17, 'max_depth': 10, 'min_split_gain': 0.0680954992207163, 'subsample': 0.7312447543007624, 'colsample_bytree': 0.8123630209269675}. Best is trial 13 with value: 18788044.567109007.
# /tmp/ipykernel_20688/1978454258.py:100: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_20688/1978454258.py:101: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# [I 2024-02-09 21:18:59,584] Trial 30 finished with value: 19290705.350920483 and parameters: {'boosting_type': 'gbdt', 'learning_rate': 0.007647842713333607, 'lambda_l1': 0.000698038186727832, 'lambda_l2': 0.004584870129488217, 'num_leaves': 88, 'feature_fraction': 0.8993376715556107, 'bagging_fraction': 0.5334925297158496, 'bagging_freq': 3, 'min_child_samples': 29, 'max_depth': 12, 'min_split_gain': 0.08941717120242887, 'subsample': 0.7002513237791216, 'colsample_bytree': 0.7776974537970022}. Best is trial 13 with value: 18788044.567109007.
# /tmp/ipykernel_20688/1978454258.py:100: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_20688/1978454258.py:101: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# [I 2024-02-09 21:18:59,722] Trial 31 finished with value: 18804523.004511975 and parameters: {'boosting_type': 'gbdt', 'learning_rate': 0.03145002362622807, 'lambda_l1': 1.638636245372533, 'lambda_l2': 1.3257698802628708, 'num_leaves': 108, 'feature_fraction': 0.7527552443492989, 'bagging_fraction': 0.5002557989515933, 'bagging_freq': 3, 'min_child_samples': 47, 'max_depth': 9, 'min_split_gain': 0.08139559372170493, 'subsample': 0.7594677393224281, 'colsample_bytree': 0.7576155271713362}. Best is trial 13 with value: 18788044.567109007.
# /tmp/ipykernel_20688/1978454258.py:100: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_20688/1978454258.py:101: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# [I 2024-02-09 21:18:59,852] Trial 32 finished with value: 18791127.02631678 and parameters: {'boosting_type': 'gbdt', 'learning_rate': 0.03076513600406721, 'lambda_l1': 0.44622948155887854, 'lambda_l2': 1.045553547486044, 'num_leaves': 99, 'feature_fraction': 0.7376771684167278, 'bagging_fraction': 0.5520836514019924, 'bagging_freq': 2, 'min_child_samples': 47, 'max_depth': 9, 'min_split_gain': 0.0714464288535399, 'subsample': 0.7530602221242102, 'colsample_bytree': 0.7298700668967683}. Best is trial 13 with value: 18788044.567109007.
# /tmp/ipykernel_20688/1978454258.py:100: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_20688/1978454258.py:101: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# [I 2024-02-09 21:18:59,982] Trial 33 finished with value: 19096651.26152178 and parameters: {'boosting_type': 'gbdt', 'learning_rate': 0.01210995477135101, 'lambda_l1': 0.4539238773681765, 'lambda_l2': 0.9155137768647856, 'num_leaves': 117, 'feature_fraction': 0.7559760279277175, 'bagging_fraction': 0.5042076152848938, 'bagging_freq': 2, 'min_child_samples': 48, 'max_depth': 10, 'min_split_gain': 0.08036565754615238, 'subsample': 0.7595485836899375, 'colsample_bytree': 0.7225300214425385}. Best is trial 13 with value: 18788044.567109007.
# /tmp/ipykernel_20688/1978454258.py:100: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_20688/1978454258.py:101: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# [I 2024-02-09 21:19:00,122] Trial 34 finished with value: 18811569.67815099 and parameters: {'boosting_type': 'gbdt', 'learning_rate': 0.03038821282401797, 'lambda_l1': 1.600522867348209, 'lambda_l2': 0.19757450885123715, 'num_leaves': 127, 'feature_fraction': 0.751272506813517, 'bagging_fraction': 0.5656610375872883, 'bagging_freq': 2, 'min_child_samples': 41, 'max_depth': 8, 'min_split_gain': 0.09550586770214377, 'subsample': 0.7831549253134191, 'colsample_bytree': 0.726540206176304}. Best is trial 13 with value: 18788044.567109007.
# /tmp/ipykernel_20688/1978454258.py:100: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_20688/1978454258.py:101: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# [I 2024-02-09 21:19:00,296] Trial 35 finished with value: 18897803.487399567 and parameters: {'boosting_type': 'gbdt', 'learning_rate': 0.018096361083161372, 'lambda_l1': 0.11420852919863254, 'lambda_l2': 0.04615052202166147, 'num_leaves': 97, 'feature_fraction': 0.7527993458421988, 'bagging_fraction': 0.600826406156226, 'bagging_freq': 1, 'min_child_samples': 47, 'max_depth': 7, 'min_split_gain': 0.06880740052351739, 'subsample': 0.9838209905059175, 'colsample_bytree': 0.7949744312462503}. Best is trial 13 with value: 18788044.567109007.
# /tmp/ipykernel_20688/1978454258.py:100: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_20688/1978454258.py:101: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# [I 2024-02-09 21:19:00,439] Trial 36 finished with value: 18870696.439950824 and parameters: {'boosting_type': 'gbdt', 'learning_rate': 0.023007371379989656, 'lambda_l1': 0.29139101056313366, 'lambda_l2': 2.1835959632052573, 'num_leaves': 119, 'feature_fraction': 0.685539576011573, 'bagging_fraction': 0.5422907570628124, 'bagging_freq': 2, 'min_child_samples': 44, 'max_depth': 15, 'min_split_gain': 0.004739824454000251, 'subsample': 0.8091904430974652, 'colsample_bytree': 0.8274917335075451}. Best is trial 13 with value: 18788044.567109007.
# /tmp/ipykernel_20688/1978454258.py:100: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_20688/1978454258.py:101: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# [I 2024-02-09 21:19:00,562] Trial 37 finished with value: 18787827.30973402 and parameters: {'boosting_type': 'gbdt', 'learning_rate': 0.04026232426066404, 'lambda_l1': 1.5810053282071155, 'lambda_l2': 5.528446711299949e-05, 'num_leaves': 108, 'feature_fraction': 0.5294800123133392, 'bagging_fraction': 0.5035859091540901, 'bagging_freq': 5, 'min_child_samples': 38, 'max_depth': 6, 'min_split_gain': 0.08968461007524324, 'subsample': 0.757757958457545, 'colsample_bytree': 0.9583644757027844}. Best is trial 37 with value: 18787827.30973402.
# /tmp/ipykernel_20688/1978454258.py:100: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_20688/1978454258.py:101: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# [I 2024-02-09 21:19:00,685] Trial 38 finished with value: 18731651.785864443 and parameters: {'boosting_type': 'gbdt', 'learning_rate': 0.03999493802349574, 'lambda_l1': 0.047055801494546884, 'lambda_l2': 6.123204023742232e-05, 'num_leaves': 102, 'feature_fraction': 0.5332828319412117, 'bagging_fraction': 0.5749471041026483, 'bagging_freq': 5, 'min_child_samples': 39, 'max_depth': 6, 'min_split_gain': 0.08541963995723378, 'subsample': 0.8536947201653413, 'colsample_bytree': 0.9597354247536254}. Best is trial 38 with value: 18731651.785864443.
# /tmp/ipykernel_20688/1978454258.py:100: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_20688/1978454258.py:101: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# [I 2024-02-09 21:19:00,817] Trial 39 finished with value: 18981616.082075685 and parameters: {'boosting_type': 'gbdt', 'learning_rate': 0.016622517049099464, 'lambda_l1': 0.04253338254256091, 'lambda_l2': 1.2653096404709832e-06, 'num_leaves': 100, 'feature_fraction': 0.5280224739938221, 'bagging_fraction': 0.5793075391066139, 'bagging_freq': 5, 'min_child_samples': 39, 'max_depth': 6, 'min_split_gain': 0.08745522888378722, 'subsample': 0.8767927817860172, 'colsample_bytree': 0.9707530067791251}. Best is trial 38 with value: 18731651.785864443.
# /tmp/ipykernel_20688/1978454258.py:100: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_20688/1978454258.py:101: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# ...
# /tmp/ipykernel_20688/1978454258.py:100: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_20688/1978454258.py:101: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# [I 2024-02-09 21:19:07,490] Trial 91 finished with value: 18757706.39786547 and parameters: {'boosting_type': 'gbdt', 'learning_rate': 0.0457193697228884, 'lambda_l1': 0.1004168832152965, 'lambda_l2': 4.3740701736236954e-05, 'num_leaves': 90, 'feature_fraction': 0.586828522212884, 'bagging_fraction': 0.5547958179695032, 'bagging_freq': 5, 'min_child_samples': 48, 'max_depth': 5, 'min_split_gain': 0.03503340769484725, 'subsample': 0.8896032733304112, 'colsample_bytree': 0.9444243781627671}. Best is trial 83 with value: 18708383.28465593.
# /tmp/ipykernel_20688/1978454258.py:100: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_20688/1978454258.py:101: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# [I 2024-02-09 21:19:07,608] Trial 92 finished with value: 18725529.670066856 and parameters: {'boosting_type': 'gbdt', 'learning_rate': 0.049630013477288126, 'lambda_l1': 0.05756380580965261, 'lambda_l2': 7.313534567697578e-05, 'num_leaves': 90, 'feature_fraction': 0.5871979173210363, 'bagging_fraction': 0.5745196243031688, 'bagging_freq': 5, 'min_child_samples': 49, 'max_depth': 5, 'min_split_gain': 0.03378411827367217, 'subsample': 0.8869392546245664, 'colsample_bytree': 0.9463597218272249}. Best is trial 83 with value: 18708383.28465593.
# /tmp/ipykernel_20688/1978454258.py:100: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_20688/1978454258.py:101: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# [I 2024-02-09 21:19:07,727] Trial 93 finished with value: 18759051.066580225 and parameters: {'boosting_type': 'gbdt', 'learning_rate': 0.04948478481014311, 'lambda_l1': 0.28624660845910044, 'lambda_l2': 3.575171977182804e-05, 'num_leaves': 85, 'feature_fraction': 0.5915719876366654, 'bagging_fraction': 0.5758960261539534, 'bagging_freq': 5, 'min_child_samples': 49, 'max_depth': 5, 'min_split_gain': 0.029349117867744787, 'subsample': 0.8906970721530344, 'colsample_bytree': 0.9506439788039082}. Best is trial 83 with value: 18708383.28465593.
# /tmp/ipykernel_20688/1978454258.py:100: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_20688/1978454258.py:101: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# [I 2024-02-09 21:19:07,844] Trial 94 finished with value: 18812511.430007312 and parameters: {'boosting_type': 'gbdt', 'learning_rate': 0.04761687362618082, 'lambda_l1': 0.053438482288850196, 'lambda_l2': 5.865967806238921e-05, 'num_leaves': 89, 'feature_fraction': 0.5841109623678646, 'bagging_fraction': 0.6067166745765594, 'bagging_freq': 5, 'min_child_samples': 48, 'max_depth': 5, 'min_split_gain': 0.036448448181393485, 'subsample': 0.9103876776713301, 'colsample_bytree': 0.938193938153056}. Best is trial 83 with value: 18708383.28465593.
# /tmp/ipykernel_20688/1978454258.py:100: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_20688/1978454258.py:101: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# [I 2024-02-09 21:19:07,965] Trial 95 finished with value: 18893656.296733145 and parameters: {'boosting_type': 'gbdt', 'learning_rate': 0.04559382159865427, 'lambda_l1': 0.14053544299855125, 'lambda_l2': 0.0004467252942484527, 'num_leaves': 79, 'feature_fraction': 0.5623621858348588, 'bagging_fraction': 0.5905415158008304, 'bagging_freq': 6, 'min_child_samples': 49, 'max_depth': 5, 'min_split_gain': 0.02673816623101197, 'subsample': 0.9210354510472335, 'colsample_bytree': 0.9465851746891427}. Best is trial 83 with value: 18708383.28465593.
# /tmp/ipykernel_20688/1978454258.py:100: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_20688/1978454258.py:101: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# [I 2024-02-09 21:19:08,085] Trial 96 finished with value: 18773259.42970749 and parameters: {'boosting_type': 'gbdt', 'learning_rate': 0.04113480104717798, 'lambda_l1': 0.5219070629182384, 'lambda_l2': 8.460194341655598e-05, 'num_leaves': 86, 'feature_fraction': 0.595809604531232, 'bagging_fraction': 0.5467603831044148, 'bagging_freq': 5, 'min_child_samples': 48, 'max_depth': 5, 'min_split_gain': 0.03694703903244848, 'subsample': 0.8857735483261076, 'colsample_bytree': 0.925611158564777}. Best is trial 83 with value: 18708383.28465593.
# /tmp/ipykernel_20688/1978454258.py:100: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_20688/1978454258.py:101: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# [I 2024-02-09 21:19:08,222] Trial 97 finished with value: 18690106.156151403 and parameters: {'boosting_type': 'gbdt', 'learning_rate': 0.04655665561785418, 'lambda_l1': 0.23678379939997116, 'lambda_l2': 3.973695166714617e-05, 'num_leaves': 94, 'feature_fraction': 0.5353874006094195, 'bagging_fraction': 0.5708869215973209, 'bagging_freq': 5, 'min_child_samples': 45, 'max_depth': 12, 'min_split_gain': 0.028416724686970023, 'subsample': 0.8695277407940432, 'colsample_bytree': 0.9526815948897938}. Best is trial 97 with value: 18690106.156151403.
# /tmp/ipykernel_20688/1978454258.py:100: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_20688/1978454258.py:101: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# [I 2024-02-09 21:19:08,360] Trial 98 finished with value: 18758022.552322444 and parameters: {'boosting_type': 'gbdt', 'learning_rate': 0.049749700889266044, 'lambda_l1': 0.27495467324681994, 'lambda_l2': 1.98050011942138e-05, 'num_leaves': 83, 'feature_fraction': 0.5324117333702402, 'bagging_fraction': 0.5710724569441108, 'bagging_freq': 5, 'min_child_samples': 45, 'max_depth': 13, 'min_split_gain': 0.026948296164468186, 'subsample': 0.9009022563344007, 'colsample_bytree': 0.9535395891496274}. Best is trial 97 with value: 18690106.156151403.
# /tmp/ipykernel_20688/1978454258.py:100: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
# /tmp/ipykernel_20688/1978454258.py:101: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
# [I 2024-02-09 21:19:08,497] Trial 99 finished with value: 18774960.507191643 and parameters: {'boosting_type': 'gbdt', 'learning_rate': 0.04168768473674541, 'lambda_l1': 0.008329515951345172, 'lambda_l2': 0.0006032874227717321, 'num_leaves': 95, 'feature_fraction': 0.5478450515243453, 'bagging_fraction': 0.584651541815371, 'bagging_freq': 5, 'min_child_samples': 47, 'max_depth': 13, 'min_split_gain': 0.051479959048695775, 'subsample': 0.8661735375561087, 'colsample_bytree': 0.9887581710693809}. Best is trial 97 with value: 18690106.156151403.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/sklearn/utils/__init__.py:423, in _get_column_indices(X, key)
#     422 try:
# --> 423     all_columns = X.columns
#     424 except AttributeError:
#
# AttributeError: 'numpy.ndarray' object has no attribute 'columns'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 145
#     139 final_model = Pipeline([
#     140     ('preprocessor', preprocessor),
#     141     ('model', LGBMRegressor(**best_params))
#     142 ])
#     144 # Fit the final model with the selected features
# --> 145 final_model.fit(X_train_selected, y_train)
#     147 # Predict and evaluate the final model
#     148 val_predictions = final_model.predict(X_val_selected)
#
# File ~/.local/lib/python3.10/site-packages/sklearn/base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/sklearn/pipeline.py:423, in Pipeline.fit(self, X, y, **fit_params)
#     397 """Fit the model.
#     398
#     399 Fit all the transformers one after the other and transform the
#    (...)
#     420     Pipeline with fitted steps.
#     421 """
#     422 fit_params_steps = self._check_fit_params(**fit_params)
# --> 423 Xt = self._fit(X, y, **fit_params_steps)
#     424 with _print_elapsed_time("Pipeline", self._log_message(len(self.steps) - 1)):
#     425     if self._final_estimator != "passthrough":
#
# File ~/.local/lib/python3.10/site-packages/sklearn/pipeline.py:377, in Pipeline._fit(self, X, y, **fit_params_steps)
#     375     cloned_transformer = clone(transformer)
#     376 # Fit or load from cache the current transformer
# --> 377 X, fitted_transformer = fit_transform_one_cached(
#     378     cloned_transformer,
#     379     X,
#     380     y,
#     381     None,
#     382     message_clsname="Pipeline",
#     383     message=self._log_message(step_idx),
#     384     **fit_params_steps[name],
#     385 )
#     386 # Replace the transformer of the step with the fitted
#     387 # transformer. This is necessary when loading the transformer
#     388 # from the cache.
#     389 self.steps[step_idx] = (name, fitted_transformer)
#
# File ~/.local/lib/python3.10/site-packages/joblib/memory.py:353, in NotMemorizedFunc.__call__(self, *args, **kwargs)
#     352 def __call__(self, *args, **kwargs):
# --> 353     return self.func(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/sklearn/pipeline.py:957, in _fit_transform_one(transformer, X, y, weight, message_clsname, message, **fit_params)
#     955 with _print_elapsed_time(message_clsname, message):
#     956     if hasattr(transformer, "fit_transform"):
# --> 957         res = transformer.fit_transform(X, y, **fit_params)
#     958     else:
#     959         res = transformer.fit(X, y, **fit_params).transform(X)
#
# File ~/.local/lib/python3.10/site-packages/sklearn/utils/_set_output.py:157, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     155 @wraps(f)
#     156 def wrapped(self, X, *args, **kwargs):
# --> 157     data_to_wrap = f(self, X, *args, **kwargs)
#     158     if isinstance(data_to_wrap, tuple):
#     159         # only wrap the first output for cross decomposition
#     160         return_tuple = (
#     161             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     162             *data_to_wrap[1:],
#     163         )
#
# File ~/.local/lib/python3.10/site-packages/sklearn/base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/sklearn/compose/_column_transformer.py:751, in ColumnTransformer.fit_transform(self, X, y)
#     749 self._check_n_features(X, reset=True)
#     750 self._validate_transformers()
# --> 751 self._validate_column_callables(X)
#     752 self._validate_remainder(X)
#     754 result = self._fit_transform(X, y, _fit_transform_one)
#
# File ~/.local/lib/python3.10/site-packages/sklearn/compose/_column_transformer.py:459, in ColumnTransformer._validate_column_callables(self, X)
#     457         columns = columns(X)
#     458     all_columns.append(columns)
# --> 459     transformer_to_input_indices[name] = _get_column_indices(X, columns)
#     461 self._columns = all_columns
#     462 self._transformer_to_input_indices = transformer_to_input_indices
#
# File ~/.local/lib/python3.10/site-packages/sklearn/utils/__init__.py:425, in _get_column_indices(X, key)
#     423     all_columns = X.columns
#     424 except AttributeError:
# --> 425     raise ValueError(
#     426         "Specifying the columns using strings is only "
#     427         "supported for pandas DataFrames"
#     428     )
#     429 if isinstance(key, str):
#     430     columns = [key]
#
# ValueError: Specifying the columns using strings is only supported for pandas DataFrames
